# %% [markdown]
# # **Python Setup**

# %%
#@title # Python Setup { display-mode: "form" }

#@markdown <font color="red"> ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ </font>

#@markdown <font color="red"><h3><b><i> Begin by running this cell.</i></b></h3> </font>

#@markdown <font color="red"> ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ </font>

# %pip install exifread &> /dev/null #added because of No module named 'exifread' error


import os, sys
if 'google.colab' in str(get_ipython()):
  print('Google Colab Environment - Loading Dependencies...')
  # !rm -r ImageSTEM imageSTEAM &> /dev/null
  # !git clone https://github.com/ImagingLyceum-ASU/ImageSTEAM.git &> /dev/null
  # !mv ImageSTEAM/imageSTEAM ./
  # !rm -r ImageSTEAM
else:
  print('Local iPython Environment')
  dir1 = os.path.dirname(os.path.abspath('../../'))
  if not dir1 in sys.path: sys.path.append(dir1)

import imageSTEAM as steam
from imageSTEAM import *

print('Environment Ready!')
# Out:
# Google Colab Environment - Loading Dependencies...
# Environment Ready!

# %% [markdown]
# # **Introduction**
#
# - What's a function
# - How can computers use functions to accomplish tasks

# %% [markdown]
# #
# <font color="red"> %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# </font>

# %% [markdown]
# # **PyPet**
#
# Let's make our PyPets again

# %%
fluffy = makePet()
# Out:
# What's the pet's name? Fluffy
# How old is the pet? 2
# How much does the pet weigh in pounds? 10
# What does the pet look like? dog
#
# Your Pet's Characteristics
# Name:  Fluffy
# Age:  2
# Weight:  10
# Photo:  dog

# %% [markdown]
# Let's use a function to feed our pet. The function we want to use is feedPet().

# %%
feedPet(fluffy)
# Out:
# Your pet's weight is now:  11

# %% [markdown]
# If you want to see the inner workings of this function, we will show you it below. Can you change the function so the pet gains 10 pounds each time it is fed?

# %%
def feedPet(pet):
  pet['weight'] = pet['weight'] #modify the code so the pet gains 10 pounds each time you feed it
  print("Your pet's weight is now: ", pet['weight'])

# %% [markdown]
# Let's try out your new feed function.

# %%
feedPet(fluffy)
# Out:
# Your pet's weight is now:  11

# %% [markdown]
# # **Activity: Create a pet, use functions sleep and feed and play**
#
# Creative activity: create your pet, and use functions to sleep, feed, and play with the pet.

# %%
# Use this cell block to create your own pet, and use the functions to sleep, feed, and play with the pet

# %% [markdown]
# # **Thinking Activity**
#
# One question to ask: is my pet alive? Does it have thoughts?
