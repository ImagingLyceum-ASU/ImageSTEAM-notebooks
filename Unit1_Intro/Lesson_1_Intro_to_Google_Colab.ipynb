# %%
#@title # Python Setup { display-mode: "form" }

#@markdown <font color="red"> ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ </font>

#@markdown <font color="red"><h3><b><i> Begin by running this cell.</i></b></h3> </font>

#@markdown <font color="red"> ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ </font>

# %pip install exifread &> /dev/null


import os, sys
if 'google.colab' in str(get_ipython()):
  print('Google Colab Environment - Loading Dependencies...')
  # !rm -r ImageSTEM imageSTEAM &> /dev/null

  # !git clone https://github.com/ImagingLyceum-ASU/ImageSTEAM.git &> /dev/null
  # !mv ImageSTEAM/imageSTEAM ./
  # !rm -r ImageSTEAM
else:
  print('Local iPython Environment')
  dir1 = os.path.dirname(os.path.abspath('../../'))
  if not dir1 in sys.path: sys.path.append(dir1)

import imageSTEAM as steam
from imageSTEAM import *

import ipywidgets as widgets
from ipywidgets import HBox, VBox, Layout

print('Environment Ready!')
# Out:
# Google Colab Environment - Loading Dependencies...
# Cloning into 'ImageSTEAM'...
# remote: Enumerating objects: 1422, done.
# remote: Counting objects: 100% (110/110), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 1422 (delta 95), reused 90 (delta 83), pack-reused 1312
# Receiving objects: 100% (1422/1422), 491.60 MiB | 27.99 MiB/s, done.
# Resolving deltas: 100% (297/297), done.
# Updating files: 100% (983/983), done.
# Environment Ready!

# %% [markdown]
# # Introduction
#
# - AI - what do you think it is?
# - Types of AI
# - Class exercise: Name some applications of AI in your daily life

# %% [markdown]
# # What is a computer?
# - the first computers were humans
# - Pictures of computers from old days
# - Modern computers
# - Class exercise: draw your version of a futuristic computer

# %% [markdown]
# # Programming a computer
# - How do we tell computers what to do?
# - Computer programs
# - Who is a computer programmer? What do they do?
# - Thinking exercise: how would you make a computer intelligent? (alternatively: how do you make a human intelligent?)

# %% [markdown]
# #
# <font color="red"> %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# </font>

# %% [markdown]
# # Python and Google Colab
# - We are going to use Python programming language
# - Google Colab (this website)

# %% [markdown]
# # **How to write your name in Python**
#
# The first thing we are going to do is write your name in Python. Below this line is a code block. When you want to run code, you press the arrow button, and it will print out the default name in the line.

# %%
print("FRED")
# Out:
# FRED

# %% [markdown]
# We should change it to be your name. Change the code so its your name printing out below.

# %%
print("YOUR NAME HERE")
# Out:
# YOUR NAME HERE

# %% [markdown]
# Did it work? Why or why not? Let's take it one step further, let's print out your first and last name.

# %%
print("First Name")
print("Last Name")
# Out:
# First Name
# Last Name

# %% [markdown]
# Let's do something different, let's have the computer ask you for your name.

# %%
printName()
# Out:
# Please input your First Name: Freddie
# Please input your Last Name: Mercury
#
# Nice to meet you, Freddie Mercury!

# %% [markdown]
# # **Write a Story**
# Let's create a story using one word per user. With a team, each person write a word into the computer. When the word "END" is used, the computer will print out the entire story

# %%
writeStory()
# Out:
# Please input next word in the story. Input END to finish the story: Jack
# Please input next word in the story. Input END to finish the story: and
# Please input next word in the story. Input END to finish the story: Jill
# Please input next word in the story. Input END to finish the story: went
# Please input next word in the story. Input END to finish the story: up
# Please input next word in the story. Input END to finish the story: the
# Please input next word in the story. Input END to finish the story: hill
# Please input next word in the story. Input END to finish the story: end
#
#   Jack and Jill went up the hill

# %% [markdown]
# # **Activity Chatbots**
#
# Let's chat with an actual chatbot. What do you think the chatbot did well in talking? What did it not do well?

# %%
import nltk
nltk.chat.iesha.demo() #other options .zen, .rude, .eliza
# Out:
# Iesha the TeenBoT
# ---------
# Talk to the program by typing in plain English, using normal upper-
# and lower-case letters and punctuation.  Enter "quit" when done.
# ...
# hi!! i'm iesha! who r u??!
# >Freddie
# do u like anime?
# >yes
# i wish i was a kitty!! kekekeke ^_^
# >quit
# mom says i have to go eat dinner now :,( bye!!
